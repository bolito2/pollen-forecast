# %% [markdown]
# Import dependencies and pollen data

# %%
import h5py
import matplotlib.pyplot as plt
import requests
from datetime import datetime, date, timedelta
from dateutil.relativedelta import relativedelta
import numpy as np
import math

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model, losses, optimizers, metrics
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Lambda, Concatenate
from tensorflow.keras.optimizers import Adam, SGD

# %% [markdown]
# Let's check that the GPU is detected

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# We import all the data, already prepared

# %%
f = h5py.File('proc_data.h5', 'r')

X_train, Y_train, X_dev, Y_dev, X_test, Y_test = np.array(f['X_train']), np.array(f['Y_train']), np.array(f['X_dev']), np.array(f['Y_dev']), f['X_test'], f['Y_test']

m_train = X_train.shape[0]
window_size = X_train.shape[1]
pred_size = Y_train.shape[1]
anal_size = window_size - pred_size
n = X_train.shape[2]

print('m_train =', m_train)
print('window_size =', window_size)
print(' - anal_size =', anal_size)
print(' - pred_size =', pred_size)
print('n =', n)

print('X_train.shape =', X_train.shape)
print('Y_train.shape =', Y_train.shape)
# Out:
# m_train = 57258
# window_size = 15
#  - anal_size = 10
#  - pred_size = 5
# n = 14
# X_train.shape = (57258, 15, 14)
# Y_train.shape = (57258, 5)

# %% [markdown]
# We introduce this methods to split each X_train case into the analysis and prediction part

# %%
def get_X_anal(X_in):
    X_anal = X_in[:, :anal_size, :]
    return X_anal

# %%
def get_X_pred(X_in):
    X_before_pollen = X_in[:, anal_size:window_size, :2]
    X_after_pollen = X_in[:, anal_size:window_size, 3:]
    
    X_pred = tf.concat([X_before_pollen, X_after_pollen], axis=2)
    
    return X_pred

# %%
def get_Y_i(Y_pred, i):
    return Y_pred[:, i, :]

# %%
X_in = Input(shape=(window_size, n), name='Input')
print('X_in.shape =',X_in.shape)

X_anal = Lambda(get_X_anal, output_shape=(anal_size, n), name='slice_anal')(X_in)
print('X_anal.shape =',X_anal.shape)

X_pred = Lambda(get_X_pred, output_shape=(pred_size, n), name='slice_pred')(X_in)
print('X_pred.shape =',X_pred.shape)
#analyze the data, we don't need an output, only the hidden state of the LSTM
X_bot, h_bot, c_bot = LSTM(64, return_state=True, return_sequences=True, name='analysis_bot')(X_anal)
print('X_bot.shape =', X_bot.shape)
_, h_top, c_top = LSTM(64, return_state=True, name='analysis_top')(X_bot)


bot_state = [h_bot, c_bot]
top_state = [h_top, c_top]
Y_bot = LSTM(64, return_sequences=True, name='prediction_bot')(X_pred, initial_state=bot_state)
print('Y_bot.shape =', Y_bot.shape)
Y_pred = LSTM(64, return_sequences=True, name='prediction_top')(Y_bot, initial_state=top_state)
print('Y_pred.shape =',Y_pred.shape)

Y_list = []
for i in range(pred_size):
    slicer = Lambda(get_Y_i, arguments={'i': i}, name='slicer-{}'.format(i))
    densor = Dense(units=1, name='densor-{}'.format(i))
    Y_list.append(densor(slicer(Y_pred)))
print('Y_list[0].shape =',Y_list[0].shape)

Y = Concatenate(axis=1)(Y_list)
print('Y.shape =',Y.shape)

model = Model(inputs=X_in, outputs=Y)
# Out:
# X_in.shape = (None, 15, 14)
# X_anal.shape = (None, 10, 14)
# X_pred.shape = (None, 5, 13)
# X_bot.shape = (None, 10, 64)
# Y_bot.shape = (None, 5, 64)
# Y_pred.shape = (None, 5, 64)
# Y_list[0].shape = (None, 1)
# Y.shape = (None, 5)

# %%
X_train_madrid, Y_train_madrid, X_dev_madrid, Y_dev_madrid = np.array(f['X_train_madrid']),np.array(f['Y_train_madrid']),np.array(f['X_dev_madrid']),np.array(f['Y_dev_madrid'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 15, 14)]     0
# __________________________________________________________________________________________________
# slice_anal (Lambda)             (None, 10, 14)       0           Input[0][0]
# __________________________________________________________________________________________________
# slice_pred (Lambda)             (None, 5, 13)        0           Input[0][0]
# __________________________________________________________________________________________________
# analysis_bot (LSTM)             [(None, 10, 64), (No 20224       slice_anal[0][0]
# __________________________________________________________________________________________________
# prediction_bot (LSTM)           (None, 5, 64)        19968       slice_pred[0][0]
#                                                                  analysis_bot[0][1]
#                                                                  analysis_bot[0][2]
# __________________________________________________________________________________________________
# analysis_top (LSTM)             [(None, 64), (None,  33024       analysis_bot[0][0]
# __________________________________________________________________________________________________
# prediction_top (LSTM)           (None, 5, 64)        33024       prediction_bot[0][0]
#                                                                  analysis_top[0][1]
#                                                                  analysis_top[0][2]
# __________________________________________________________________________________________________
# slicer-0 (Lambda)               (None, 64)           0           prediction_top[0][0]
# __________________________________________________________________________________________________
# slicer-1 (Lambda)               (None, 64)           0           prediction_top[0][0]
# __________________________________________________________________________________________________
# slicer-2 (Lambda)               (None, 64)           0           prediction_top[0][0]
# __________________________________________________________________________________________________
# slicer-3 (Lambda)               (None, 64)           0           prediction_top[0][0]
# __________________________________________________________________________________________________
# slicer-4 (Lambda)               (None, 64)           0           prediction_top[0][0]
# __________________________________________________________________________________________________
# densor-0 (Dense)                (None, 1)            65          slicer-0[0][0]
# __________________________________________________________________________________________________
# densor-1 (Dense)                (None, 1)            65          slicer-1[0][0]
# __________________________________________________________________________________________________
# densor-2 (Dense)                (None, 1)            65          slicer-2[0][0]
# __________________________________________________________________________________________________
# densor-3 (Dense)                (None, 1)            65          slicer-3[0][0]
# __________________________________________________________________________________________________
# densor-4 (Dense)                (None, 1)            65          slicer-4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 5)            0           densor-0[0][0]
#                                                                  densor-1[0][0]
#                                                                  densor-2[0][0]
#                                                                  densor-3[0][0]
#                                                                  densor-4[0][0]
# ==================================================================================================
# Total params: 106,565
# Trainable params: 106,565
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
opt = Adam(learning_rate=0.0001, beta_1 = 0.9, beta_2 = 0.99, epsilon=1e-7, clipnorm=1)

model.compile(loss='mse', optimizer=opt, metrics=['mae'])

# %%
fitting = model.fit(X_train, Y_train, batch_size=128, epochs = 20, validation_data=(X_dev, Y_dev), shuffle=True)
# Out:
# Epoch 1/20
# 448/448 [==============================] - 9s 20ms/step - loss: 1.3561 - mae: 0.9070 - val_loss: 1.3542 - val_mae: 0.9055
# Epoch 2/20
# 448/448 [==============================] - 8s 18ms/step - loss: 1.3615 - mae: 0.9080 - val_loss: 1.3738 - val_mae: 0.9113
# Epoch 3/20
# 448/448 [==============================] - 8s 18ms/step - loss: 1.3634 - mae: 0.9090 - val_loss: 1.4731 - val_mae: 0.9428
# Epoch 4/20
# 448/448 [==============================] - 8s 18ms/step - loss: 1.3469 - mae: 0.9025 - val_loss: 1.3876 - val_mae: 0.9143
# Epoch 5/20
# 448/448 [==============================] - 8s 18ms/step - loss: 1.3642 - mae: 0.9083 - val_loss: 1.3538 - val_mae: 0.9079
# Epoch 6/20
# 448/448 [==============================] - 8s 18ms/step - loss: 1.3597 - mae: 0.9070 - val_loss: 1.3896 - val_mae: 0.9234
# Epoch 7/20
# 448/448 [==============================] - 8s 18ms/step - loss: 1.3573 - mae: 0.9068 - val_loss: 1.3382 - val_mae: 0.8968
# Epoch 8/20
# 448/448 [==============================] - 8s 18ms/step - loss: 1.3522 - mae: 0.9041 - val_loss: 1.3629 - val_mae: 0.9036
# Epoch 9/20
# 448/448 [==============================] - 8s 18ms/step - loss: 1.3501 - mae: 0.9035 - val_loss: 1.3627 - val_mae: 0.9076
# Epoch 10/20
# 448/448 [==============================] - 8s 18ms/step - loss: 1.3408 - mae: 0.9000 - val_loss: 1.3603 - val_mae: 0.9074
# Epoch 11/20
# 448/448 [==============================] - 8s 18ms/step - loss: 1.3391 - mae: 0.8990 - val_loss: 1.3674 - val_mae: 0.9073
# Epoch 12/20
# 448/448 [==============================] - 8s 18ms/step - loss: 1.3374 - mae: 0.8992 - val_loss: 1.4328 - val_mae: 0.9364
# Epoch 13/20
# 448/448 [==============================] - 8s 18ms/step - loss: 1.3415 - mae: 0.9006 - val_loss: 1.3120 - val_mae: 0.8916
# Epoch 14/20
# 448/448 [==============================] - 8s 19ms/step - loss: 1.3385 - mae: 0.8988 - val_loss: 1.3724 - val_mae: 0.9218
# Epoch 15/20
# 448/448 [==============================] - 8s 18ms/step - loss: 1.3403 - mae: 0.8997 - val_loss: 1.3953 - val_mae: 0.9192
# Epoch 16/20
# 448/448 [==============================] - 8s 18ms/step - loss: 1.3364 - mae: 0.8976 - val_loss: 1.4373 - val_mae: 0.9359
# Epoch 17/20
# 448/448 [==============================] - 8s 18ms/step - loss: 1.3403 - mae: 0.8992 - val_loss: 1.3247 - val_mae: 0.8970
# Epoch 18/20
# 448/448 [==============================] - 8s 19ms/step - loss: 1.3260 - mae: 0.8940 - val_loss: 1.4742 - val_mae: 0.9507
# Epoch 19/20
# 448/448 [==============================] - 8s 18ms/step - loss: 1.3267 - mae: 0.8947 - val_loss: 1.3160 - val_mae: 0.8930
# Epoch 20/20
# 448/448 [==============================] - 8s 19ms/step - loss: 1.3340 - mae: 0.8961 - val_loss: 1.3150 - val_mae: 0.8899

# %%
fitting = model.fit(X_train_madrid, Y_train_madrid, batch_size=10000, epochs = 100, validation_data=(X_dev_madrid, Y_dev_madrid), shuffle=True)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 925ms/step - loss: 1.4278 - mae: 0.9269 - val_loss: 1.4767 - val_mae: 0.9397
# Epoch 2/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.4194 - mae: 0.9299 - val_loss: 1.4733 - val_mae: 0.9383
# Epoch 3/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1.4152 - mae: 0.9281 - val_loss: 1.4621 - val_mae: 0.9315
# Epoch 4/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1.4012 - mae: 0.9209 - val_loss: 1.4761 - val_mae: 0.9338
# Epoch 5/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1.4107 - mae: 0.9227 - val_loss: 1.4807 - val_mae: 0.9356
# Epoch 6/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1.4129 - mae: 0.9238 - val_loss: 1.4756 - val_mae: 0.9359
# Epoch 7/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.4074 - mae: 0.9238 - val_loss: 1.4730 - val_mae: 0.9368
# Epoch 8/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.4071 - mae: 0.9255 - val_loss: 1.4727 - val_mae: 0.9365
# Epoch 9/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1.4079 - mae: 0.9260 - val_loss: 1.4701 - val_mae: 0.9344
# Epoch 10/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.4052 - mae: 0.9241 - val_loss: 1.4674 - val_mae: 0.9322
# Epoch 11/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.4035 - mae: 0.9219 - val_loss: 1.4649 - val_mae: 0.9308
# Epoch 12/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.4023 - mae: 0.9206 - val_loss: 1.4615 - val_mae: 0.9300
# Epoch 13/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.4003 - mae: 0.9199 - val_loss: 1.4610 - val_mae: 0.9309
# Epoch 14/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1.4017 - mae: 0.9207 - val_loss: 1.4614 - val_mae: 0.9310
# Epoch 15/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.4033 - mae: 0.9209 - val_loss: 1.4610 - val_mae: 0.9300
# Epoch 16/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.4036 - mae: 0.9201 - val_loss: 1.4618 - val_mae: 0.9295
# Epoch 17/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.4038 - mae: 0.9196 - val_loss: 1.4633 - val_mae: 0.9297
# Epoch 18/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.4034 - mae: 0.9194 - val_loss: 1.4621 - val_mae: 0.9295
# Epoch 19/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.4008 - mae: 0.9190 - val_loss: 1.4609 - val_mae: 0.9302
# Epoch 20/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3992 - mae: 0.9196 - val_loss: 1.4617 - val_mae: 0.9310
# Epoch 21/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.3994 - mae: 0.9203 - val_loss: 1.4623 - val_mae: 0.9307
# Epoch 22/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1.3989 - mae: 0.9200 - val_loss: 1.4658 - val_mae: 0.9308
# Epoch 23/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.4006 - mae: 0.9198 - val_loss: 1.4681 - val_mae: 0.9315
# Epoch 24/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1.4019 - mae: 0.9203 - val_loss: 1.4673 - val_mae: 0.9318
# Epoch 25/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.4008 - mae: 0.9206 - val_loss: 1.4668 - val_mae: 0.9329
# Epoch 26/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.4007 - mae: 0.9218 - val_loss: 1.4668 - val_mae: 0.9337
# Epoch 27/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.4020 - mae: 0.9229 - val_loss: 1.4657 - val_mae: 0.9333
# Epoch 28/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.4010 - mae: 0.9223 - val_loss: 1.4637 - val_mae: 0.9317
# Epoch 29/100
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3985 - mae: 0.9204 - val_loss: 1.4652 - val_mae: 0.9308
# Epoch 30/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1.3995 - mae: 0.9194 - val_loss: 1.4661 - val_mae: 0.9306
# Epoch 31/100
# 1/1 [==============================] - 0s 41ms/step - loss: 1.4008 - mae: 0.9193 - val_loss: 1.4634 - val_mae: 0.9300
# Epoch 32/100
# 1/1 [==============================] - 0s 41ms/step - loss: 1.3990 - mae: 0.9190 - val_loss: 1.4605 - val_mae: 0.9300
# Epoch 33/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.3975 - mae: 0.9193 - val_loss: 1.4610 - val_mae: 0.9311
# Epoch 34/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.3985 - mae: 0.9203 - val_loss: 1.4609 - val_mae: 0.9310
# Epoch 35/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.3981 - mae: 0.9201 - val_loss: 1.4608 - val_mae: 0.9299
# Epoch 36/100
# 1/1 [==============================] - 0s 41ms/step - loss: 1.3973 - mae: 0.9191 - val_loss: 1.4609 - val_mae: 0.9298
# Epoch 37/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1.3973 - mae: 0.9189 - val_loss: 1.4603 - val_mae: 0.9301
# Epoch 38/100
# 1/1 [==============================] - 0s 34ms/step - loss: 1.3970 - mae: 0.9193 - val_loss: 1.4604 - val_mae: 0.9299
# Epoch 39/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1.3969 - mae: 0.9190 - val_loss: 1.4615 - val_mae: 0.9301
# Epoch 40/100
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3969 - mae: 0.9190 - val_loss: 1.4620 - val_mae: 0.9309
# Epoch 41/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.3969 - mae: 0.9196 - val_loss: 1.4616 - val_mae: 0.9311
# Epoch 42/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.3970 - mae: 0.9198 - val_loss: 1.4615 - val_mae: 0.9305
# Epoch 43/100
# 1/1 [==============================] - 0s 41ms/step - loss: 1.3965 - mae: 0.9192 - val_loss: 1.4608 - val_mae: 0.9297
# Epoch 44/100
# 1/1 [==============================] - 0s 41ms/step - loss: 1.3966 - mae: 0.9186 - val_loss: 1.4597 - val_mae: 0.9295
# Epoch 45/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.3966 - mae: 0.9186 - val_loss: 1.4596 - val_mae: 0.9298
# Epoch 46/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.3965 - mae: 0.9188 - val_loss: 1.4602 - val_mae: 0.9301
# Epoch 47/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.3963 - mae: 0.9188 - val_loss: 1.4616 - val_mae: 0.9302
# Epoch 48/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1.3964 - mae: 0.9186 - val_loss: 1.4618 - val_mae: 0.9306
# Epoch 49/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3961 - mae: 0.9190 - val_loss: 1.4613 - val_mae: 0.9307
# Epoch 50/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.3962 - mae: 0.9194 - val_loss: 1.4612 - val_mae: 0.9303
# Epoch 51/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3961 - mae: 0.9191 - val_loss: 1.4615 - val_mae: 0.9299
# Epoch 52/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1.3961 - mae: 0.9186 - val_loss: 1.4608 - val_mae: 0.9299
# Epoch 53/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1.3957 - mae: 0.9186 - val_loss: 1.4604 - val_mae: 0.9307
# Epoch 54/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.3961 - mae: 0.9193 - val_loss: 1.4604 - val_mae: 0.9305
# Epoch 55/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.3961 - mae: 0.9191 - val_loss: 1.4609 - val_mae: 0.9300
# Epoch 56/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1.3962 - mae: 0.9183 - val_loss: 1.4606 - val_mae: 0.9299
# Epoch 57/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1.3962 - mae: 0.9183 - val_loss: 1.4599 - val_mae: 0.9304
# Epoch 58/100
# 1/1 [==============================] - 0s 41ms/step - loss: 1.3963 - mae: 0.9189 - val_loss: 1.4597 - val_mae: 0.9302
# Epoch 59/100
# 1/1 [==============================] - 0s 33ms/step - loss: 1.3963 - mae: 0.9189 - val_loss: 1.4600 - val_mae: 0.9296
# Epoch 60/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3960 - mae: 0.9183 - val_loss: 1.4616 - val_mae: 0.9297
# Epoch 61/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.3962 - mae: 0.9180 - val_loss: 1.4615 - val_mae: 0.9300
# Epoch 62/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1.3954 - mae: 0.9182 - val_loss: 1.4613 - val_mae: 0.9312
# Epoch 63/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.3954 - mae: 0.9194 - val_loss: 1.4622 - val_mae: 0.9318
# Epoch 64/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.3958 - mae: 0.9198 - val_loss: 1.4630 - val_mae: 0.9313
# Epoch 65/100
# 1/1 [==============================] - 0s 41ms/step - loss: 1.3953 - mae: 0.9191 - val_loss: 1.4634 - val_mae: 0.9307
# Epoch 66/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.3954 - mae: 0.9185 - val_loss: 1.4621 - val_mae: 0.9305
# Epoch 67/100
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3949 - mae: 0.9185 - val_loss: 1.4613 - val_mae: 0.9313
# Epoch 68/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.3953 - mae: 0.9194 - val_loss: 1.4609 - val_mae: 0.9312
# Epoch 69/100
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3953 - mae: 0.9193 - val_loss: 1.4607 - val_mae: 0.9302
# Epoch 70/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.3945 - mae: 0.9182 - val_loss: 1.4627 - val_mae: 0.9302
# Epoch 71/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.3953 - mae: 0.9179 - val_loss: 1.4626 - val_mae: 0.9304
# Epoch 72/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.3949 - mae: 0.9180 - val_loss: 1.4617 - val_mae: 0.9312
# Epoch 73/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.3946 - mae: 0.9189 - val_loss: 1.4619 - val_mae: 0.9314
# Epoch 74/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3948 - mae: 0.9192 - val_loss: 1.4621 - val_mae: 0.9307
# Epoch 75/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1.3943 - mae: 0.9186 - val_loss: 1.4619 - val_mae: 0.9298
# Epoch 76/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1.3945 - mae: 0.9180 - val_loss: 1.4605 - val_mae: 0.9296
# Epoch 77/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.3942 - mae: 0.9179 - val_loss: 1.4595 - val_mae: 0.9301
# Epoch 78/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.3946 - mae: 0.9186 - val_loss: 1.4592 - val_mae: 0.9300
# Epoch 79/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.3946 - mae: 0.9185 - val_loss: 1.4593 - val_mae: 0.9293
# Epoch 80/100
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3942 - mae: 0.9175 - val_loss: 1.4612 - val_mae: 0.9294
# Epoch 81/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1.3950 - mae: 0.9174 - val_loss: 1.4609 - val_mae: 0.9296
# Epoch 82/100
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3944 - mae: 0.9176 - val_loss: 1.4600 - val_mae: 0.9304
# Epoch 83/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.3941 - mae: 0.9184 - val_loss: 1.4603 - val_mae: 0.9308
# Epoch 84/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.3943 - mae: 0.9188 - val_loss: 1.4604 - val_mae: 0.9302
# Epoch 85/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1.3935 - mae: 0.9182 - val_loss: 1.4618 - val_mae: 0.9295
# Epoch 86/100
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3943 - mae: 0.9176 - val_loss: 1.4616 - val_mae: 0.9294
# Epoch 87/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3944 - mae: 0.9177 - val_loss: 1.4600 - val_mae: 0.9297
# Epoch 88/100
# 1/1 [==============================] - 0s 40ms/step - loss: 1.3936 - mae: 0.9181 - val_loss: 1.4600 - val_mae: 0.9308
# Epoch 89/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.3946 - mae: 0.9191 - val_loss: 1.4599 - val_mae: 0.9308
# Epoch 90/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3944 - mae: 0.9188 - val_loss: 1.4595 - val_mae: 0.9298
# Epoch 91/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3932 - mae: 0.9176 - val_loss: 1.4621 - val_mae: 0.9296
# Epoch 92/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.3945 - mae: 0.9172 - val_loss: 1.4626 - val_mae: 0.9297
# Epoch 93/100
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3945 - mae: 0.9172 - val_loss: 1.4605 - val_mae: 0.9297
# Epoch 94/100
# 1/1 [==============================] - 0s 39ms/step - loss: 1.3929 - mae: 0.9173 - val_loss: 1.4611 - val_mae: 0.9315
# Epoch 95/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.3948 - mae: 0.9193 - val_loss: 1.4624 - val_mae: 0.9323
# Epoch 96/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.3964 - mae: 0.9203 - val_loss: 1.4611 - val_mae: 0.9313
# Epoch 97/100
# 1/1 [==============================] - 0s 38ms/step - loss: 1.3943 - mae: 0.9191 - val_loss: 1.4613 - val_mae: 0.9299
# Epoch 98/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.3928 - mae: 0.9173 - val_loss: 1.4630 - val_mae: 0.9300
# Epoch 99/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.3936 - mae: 0.9171 - val_loss: 1.4623 - val_mae: 0.9301
# Epoch 100/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3929 - mae: 0.9172 - val_loss: 1.4613 - val_mae: 0.9311

# %%
plt.plot(np.array(fitting.history['loss']), color='r')
plt.plot(np.array(fitting.history['val_loss']), color='b')
plt.show()

# %% [markdown]
# - v1.0 val_loss = 3.175 after 400 epochs
# - v1.1 val_loss = 1.797 after 400 epochs
#     - Added precipitation data
# - v1.2 val_loss = 0.716 after 400 epochs
#     - Added a log kernel to pollen data
#
# - v2.0 val_loss = 1130 after 110 epochs
#     - Trained with all the data
# - v2.1 val_loss = 0.57 after 100 epochs
#     - fixed normalization lol
# - v3.0 val_loss = 1.51 after 100 epochs
#     - Added multi-day forecasting

# %%
start_windows = 0
end_windows = 20

X_pred = X_dev[start_windows:end_windows]
Y_pred = model(X_pred)
Y_true = Y_dev[start_windows:end_windows]

for i in range(end_windows - start_windows):
    plt.plot(range(window_size), X_pred[i, :, 2], color='b')
    plt.plot(range(anal_size, window_size), Y_pred[i], color='r')
    plt.plot(range(anal_size, window_size), Y_true[i], color='g')
    plt.show()

# %%
start_windows = 20
end_windows = 40

X_pred = X_dev_madrid[start_windows:end_windows]
Y_pred = model(X_pred)
Y_true = Y_dev_madrid[start_windows:end_windows]

for i in range(end_windows - start_windows):
    plt.plot(range(window_size), X_pred[i, :, 2], color='b')
    plt.plot(range(anal_size, window_size), Y_pred[i], color='r')
    plt.plot(range(anal_size, window_size), Y_true[i], color='g')
    plt.show()

# %%
parameters = f['parameters']
pollen_mean = parameters[0, 2]
pollen_std = parameters[1, 2]

start_pred = 140
end_pred = 150

Y_true = Y_dev[start_pred:end_pred]
Y_pred = model(X_dev)[start_pred:end_pred]

for i in range(pred_size):
    plt.plot(Y_true[:, i], color='b')
    plt.plot(Y_pred[:, i], color='r')

    plt.show()

# %% [markdown]
# Here we plot the data directly as it is, with the log kernel, and in the next cell reverted back to the original values. I pass it through this log kernel because I suspect that it is what I will use when I classify the predictions into a few classes or 'levels' of pollen in air. This is because, a jump in pollen levels of a fixed amount is much more noticeable if it comes from a low value(where the user might jump from no symptoms to light symptoms) that in a already high value where the user will be fucked up either way.
